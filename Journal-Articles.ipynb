# %%
# Read in everything we will or might need.

import numpy as np
import pandas as pd
df = pd.read_csv('/Users/whaight/Downloads/DS/WELLCOME/WELLCOME_APCspend2013_forThinkful.csv', encoding = "ISO-8859-1")
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Just who are these columns, anyway?

print(df.columns)
# Out:
# Index(['PMID/PMCID', 'Publisher', 'Journal title', 'Article title',
#        'COST (£) charged to Wellcome (inc VAT when charged)'],
#       dtype='object')

# %%
# Get a feel for what our data look like.  How about we make the column titles a bit more nimble,
# and we pull the '£' and '$' symbols out of the cost column so we can treat what's left as numeric.
# Other cleaning is necessary as well -- better put text entries in upper case or lower case for 
# comparison.

df.head()
# Out:
#               PMID/PMCID Publisher           Journal title  \
# 0                    NaN       CUP  Psychological Medicine
# 1             PMC3679557       ACS       Biomacromolecules
# 2  23043264  PMC3506128        ACS              J Med Chem
# 3    23438330 PMC3646402       ACS              J Med Chem
# 4   23438216 PMC3601604        ACS              J Org Chem
#
#                                        Article title  \
# 0  Reduced parahippocampal cortical thickness in ...
# 1  Structural characterization of a Model Gram-ne...
# 2  Fumaroylamino-4,5-epoxymorphinans and related ...
# 3  Orvinols with mixed kappa/mu opioid receptor a...
# 4  Regioselective opening of myo-inositol orthoes...
#
#   COST (£) charged to Wellcome (inc VAT when charged)
# 0                                              £0.00
# 1                                           £2381.04
# 2                                            £642.56
# 3                                            £669.64
# 4                                            £685.88

# %%
# Here are the better column titles

df.columns=['PMID/PMCID', 'Pub', 'Journal', 'Article', 'COST']

# %%
# Let's put the text columns in upper case

df['PMID/PMCID']=df['PMID/PMCID'].str.upper()
df['Pub']=df['Pub'].str.upper()
df['Journal']=df['Journal'].str.upper()
df['Article']=df['Article'].str.upper()

# %%
# Here we clean up the money column and recast as float for arithmetic

df['COST']=df['COST'].str.replace('£', '')
df['COST']=df['COST'].str.replace('$', '')
df['COST']=df['COST'].astype(float)

# %%
# Add three columns with mean, median, and standard deviation for COST

df['meanCost']=df.groupby('Journal')['COST'].mean()
df['medianCost']=df.groupby('Journal')['COST'].median()
df['SDCost']=df.groupby('Journal')['COST'].std()

# %%
# let's get a look at what we have

df.head()
# Out:
#               PMID/PMCID  Pub                 Journal  \
# 0                    NaN  CUP  PSYCHOLOGICAL MEDICINE
# 1             PMC3679557  ACS       BIOMACROMOLECULES
# 2  23043264  PMC3506128   ACS              J MED CHEM
# 3    23438330 PMC3646402  ACS              J MED CHEM
# 4   23438216 PMC3601604   ACS              J ORG CHEM
#
#                                              Article     COST  meanCost  \
# 0  REDUCED PARAHIPPOCAMPAL CORTICAL THICKNESS IN ...     0.00       NaN
# 1  STRUCTURAL CHARACTERIZATION OF A MODEL GRAM-NE...  2381.04       NaN
# 2  FUMAROYLAMINO-4,5-EPOXYMORPHINANS AND RELATED ...   642.56       NaN
# 3  ORVINOLS WITH MIXED KAPPA/MU OPIOID RECEPTOR A...   669.64       NaN
# 4  REGIOSELECTIVE OPENING OF MYO-INOSITOL ORTHOES...   685.88       NaN
#
#    medianCost  SDCost
# 0         NaN     NaN
# 1         NaN     NaN
# 2         NaN     NaN
# 3         NaN     NaN
# 4         NaN     NaN

# %%
# OK, now we get an answer to the first question.  "PLOS ONE" down through "PLOS GENETICS" are our five
# most common journals, listed with the total number of articles for each.  HUZZAH!

df.groupby(['Journal'])['PMID/PMCID'].count().sort_values(ascending=False).to_frame()
# Out:
#                                                     PMID/PMCID
# Journal
# PLOS ONE                                                   188
# JOURNAL OF BIOLOGICAL CHEMISTRY                             52
# NEUROIMAGE                                                  28
# PLOS PATHOGENS                                              24
# PLOS GENETICS                                               23
# NUCLEIC ACIDS RESEARCH                                      22
# PLOS NEGLECTED TROPICAL DISEASES                            20
# PROCEEDINGS OF THE NATIONAL ACADEMY OF SCIENCES             20
# NATURE COMMUNICATIONS                                       19
# HUMAN MOLECULAR GENETICS                                    17
# BMC PUBLIC HEALTH                                           12
# BRAIN                                                       11
# JOURNAL OF GENERAL VIROLOGY                                 11
# MOVEMENT DISORDERS                                          11
# BIOCHEMICAL JOURNAL                                         11
# CURRENT BIOLOGY                                             10
# PLOSONE                                                      9
# JOURNAL OF NEUROSCIENCE                                      9
# CELL REPORTS                                                 9
# BMJ OPEN                                                     9
# DEVELOPMENTAL CELL                                           9
# MALARIA JOURNAL                                              8
# NEUROBIOLOGY OF AGING                                        8
# PROCEEDINGS OF THE ROYAL SOCIETY B: BIOLOGICAL ...           8
# JOURNAL OF STRUCTURAL BIOLOGY                                8
# EUROPEAN JOURNAL OF IMMUNOLOGY                               8
# PLOS COMPUTATIONAL BIOLOGY                                   8
# NEURON                                                       8
# JOURNAL OF CLINICAL ENDOCRINOLOGY AND METABOLISM             8
# JOURNAL OF PHYSIOLOGY                                        7
# ...                                                        ...
# ASN NEURO                                                    0
# RESPIRATION                                                  0
# AZANIA: ARCHAEOLOGICAL RESEARCH IN AFRICA                    0
# PUBLIC HEALTH ETHICS                                         0
# BIOCHIMICA ET BIOPHYSICA ACTA (BBA) - MOLECULAR...           0
# PLOS 1                                                       0
# PLOS  ONE                                                    0
# PLOS  COMPUTATIONAL BIOLOGY                                  0
# PHYSICS IN BIOLOGY AND MEDICINE\n                            0
# BIRTH DEFECTS RESEARCH PART A: CLINICAL AND MOL...           0
# BIRTH DEFECTS RESEARCH PART A: CLINICAL AND MOL...           0
# PFLUGERS ARCHIV                                              0
# NMR IN BIOMEDICINE                                           0
# NEUROSCIENTIST                                               0
# BMJ QUALITY AND SAFETY                                       0
# NEUROLOGY                                                    0
# NEUROIMAGE: CLINICAL                                         0
# NEUROIMAGE: CLINICAL                                         0
# MUSCLE AND NERVE                                             0
# MOLECULAR GENETICS & GENOMIC MEDICINE                        0
# CANADIAN JOURNAL OF AFRICAN STUDIES                          0
# MEDICAL HUMANITIES                                           0
# HEALTH & PLACE                                               0
# LANCET                                                       0
# JOURNAL OF VISULAIZED EXPERMIMENTS                           0
# CHILD NEUROPSYCHOLOGY                                        0
# CHRONIC ILLNESS                                              0
# JOURNAL OF THE INTERNATIONAL AFRICAN INSTITUTE               0
# JOURNAL OF POVERTY AND SOCIAL JUSTICE                        0
# MATURITAS                                                    0
#
# [928 rows x 1 columns]
